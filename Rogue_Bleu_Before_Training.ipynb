# %%
pip install rouge-score nltk
# Out:
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=efcfa9a097e44c12264df6026423825a46b0fc6dc99610486dfa3115e8d8a5b1
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge-score
# Installing collected packages: rouge-score
# Successfully installed rouge-score-0.1.2

# %%
# !pip install -q datasets
# !pip install -q git+https://github.com/huggingface/transformers.git
# !pip install -q bitsandbytes sentencepiece accelerate loralib
# !pip install -q -U git+https://github.com/huggingface/peft.git
# !pip install -i https://pypi.org/simple/ bitsandbytes
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 19.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 23.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 15.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 42.9 MB/s eta 0:00:00
#   Building wheel for transformers (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 8.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for peft (pyproject.toml) ... done
# Looking in indexes: https://pypi.org/simple/
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.10/dist-packages (0.44.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (2.4.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->bitsandbytes) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->bitsandbytes) (1.3.0)

# %%
# !pip install --upgrade transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.46.0.dev0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)

# %%
pip install accelerate --upgrade
# Out:
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.34.2)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.4.1+cu121)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.24.7)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2024.6.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)

# %%
import torch
from datasets import load_dataset
from peft import LoraConfig, get_peft_model
from PIL import Image
from transformers import IdeficsForVisionText2Text, DataCollatorForTokenClassification, Trainer, TrainingArguments, BitsAndBytesConfig
import torchvision.transforms as transforms
import pandas as pd
from rouge_score import rouge_scorer
import nltk
from nltk.translate.bleu_score import sentence_bleu

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
checkpoint = "HuggingFaceM4/idefics-9b"
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
    llm_int8_skip_modules=["lm_head", "embed_tokens"],
)

# %%
from transformers import AutoProcessor

# %%
processor = AutoProcessor.from_pretrained(checkpoint)
model = IdeficsForVisionText2Text.from_pretrained(checkpoint, quantization_config=bnb_config, device_map="auto")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/281 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/61.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/181 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.41k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/99.2k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/19 [00:00<?, ?it/s]
# model-00001-of-00019.safetensors:   0%|          | 0.00/2.00G [00:00<?, ?B/s]
# model-00002-of-00019.safetensors:   0%|          | 0.00/1.82G [00:00<?, ?B/s]
# model-00003-of-00019.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00004-of-00019.safetensors:   0%|          | 0.00/1.93G [00:00<?, ?B/s]
# model-00005-of-00019.safetensors:   0%|          | 0.00/1.93G [00:00<?, ?B/s]
# model-00006-of-00019.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00007-of-00019.safetensors:   0%|          | 0.00/1.89G [00:00<?, ?B/s]
# model-00008-of-00019.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00009-of-00019.safetensors:   0%|          | 0.00/1.93G [00:00<?, ?B/s]
# model-00010-of-00019.safetensors:   0%|          | 0.00/1.93G [00:00<?, ?B/s]
# model-00011-of-00019.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00012-of-00019.safetensors:   0%|          | 0.00/1.89G [00:00<?, ?B/s]
# model-00013-of-00019.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00014-of-00019.safetensors:   0%|          | 0.00/1.93G [00:00<?, ?B/s]
# model-00015-of-00019.safetensors:   0%|          | 0.00/1.93G [00:00<?, ?B/s]
# model-00016-of-00019.safetensors:   0%|          | 0.00/1.97G [00:00<?, ?B/s]
# model-00017-of-00019.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00018-of-00019.safetensors:   0%|          | 0.00/1.97G [00:00<?, ?B/s]
# model-00019-of-00019.safetensors:   0%|          | 0.00/705M [00:00<?, ?B/s]
# IdeficsForVisionText2Text has generative capabilities, as `prepare_inputs_for_generation` is explicitly overwritten. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.
# Instantiating IdeficsAttention without passing a `layer_idx` is not recommended and will lead to errors during the forward call if caching is used. Please make sure to provide a `layer_idx` when creating this class.
# Loading checkpoint shards:   0%|          | 0/19 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/My Drive/fypDataset/ReportWithImage.csv")
df = df.drop_duplicates()
df.to_json('train.jsonl', orient='records', lines=True)

train_dataset = load_dataset('json', data_files='/content/train.jsonl', split="train")
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
data = {
    'User': [],
    'Assistant': []
}
imageUrl = []

for example in train_dataset:
    user_text = f"User: This is a Picture of Wrist Xray, Is It Fracture or Not in Xray?\nImage: https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Match_fracture/{example['image_name']}?raw=true \n"
    assistant_text = f"\nAssistant: {example['indication']}. Findings: {example['findings']}. Impression: {example['impression']}\nResult: Wrist Xray is {example['Problems']}"
    imageUrl.append(f"https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Match_fracture/{example['image_name']}?raw=true")
    data['User'].append(user_text)
    data['Assistant'].append(assistant_text)

prompts = []
count = 0
size = min(len(data['User']), len(data['Assistant']))

for i in range(size):
    if count >= 0:
        pair = [data['User'][i], data['Assistant'][i]]
        count = count + 1
    else:
        break
    prompts.append(pair)

# %%
def do_inference(model, processor, prompt, max_new_tokens=150):
    tokenizer = processor.tokenizer
    bad_words = ["", "<fake_token_around_image>"]
    if len(bad_words) > 0:
        bad_words_ids = tokenizer(bad_words, add_special_tokens=False).input_ids
    eos_token = "</s>"
    eos_token_id = tokenizer.convert_tokens_to_ids(eos_token)

    input = processor(prompt, return_tensors="pt").to(device)
    generated_ids = model.generate(
        **input,
        eos_token_id=[eos_token_id],
        bad_words_ids=bad_words_ids,
        max_new_tokens=max_new_tokens,
        early_stopping=True)
    generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
    print(generated_text)
    return generated_text

# %%
from peft import get_peft_model, LoraConfig, TaskType, prepare_model_for_kbit_training

# %%
model.gradient_checkpointing_enable()
model = prepare_model_for_kbit_training(model)

# %%
peft_config = LoraConfig(
    r=16,
    lora_alpha=32,
    target_modules=["q_proj", "k_proj", "v_proj"],
    lora_dropout=0.05,
    bias="none"
)

# %%
model = get_peft_model(model, peft_config)

alpaca_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
{}"""

# %%
from transformers import AutoTokenizer, AutoModel
tokenizer = AutoTokenizer.from_pretrained(checkpoint, padding_side="right",)
tokenizer.pad_token = tokenizer.eos_token

# %%
tokenizer = AutoTokenizer.from_pretrained(checkpoint, padding_side="right")
tokenizer.pad_token = tokenizer.eos_token
EOS_TOKEN = tokenizer.eos_token
EOS_TOKEN = tokenizer.eos_token
def format_dataset(examples):
    image_name = examples['image_name']
    prompt = alpaca_prompt.format(examples["instructions"], f"{examples['inputs']}\nhttps://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/{image_name}?raw=true", examples["outputs"]) + EOS_TOKEN
    tokens = tokenizer(prompt, truncation=True, max_length=256, padding="max_length",)
    tokens["labels"] = tokens['input_ids'].copy()
    return tokens

# %%
dataset = load_dataset('csv', data_files='/content/drive/My Drive/fypDataset/format Report.csv', split="train")
dataset = dataset.map(format_dataset)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/618 [00:00<?, ? examples/s]

# %%
def convert_to_rgb(image_path):
    image = Image.open(image_path)
    if image.mode == "RGB":
        return image
    image_rgba = image.convert("RGBA")
    background = Image.new("RGBA", image_rgba.size, (255, 255, 255))
    alpha_composite = Image.alpha_composite(background, image_rgba)
    return alpha_composite.convert("RGB")

# %%
def tmp_transforms(examples):
    image_size = processor.image_processor.image_size
    image_mean = processor.image_processor.image_mean
    image_std = processor.image_processor.image_std
    image_transform = transforms.Compose([
        convert_to_rgb,
        transforms.RandomResizedCrop((image_size, image_size), scale=(0.9, 1.0), interpolation=transforms.InterpolationMode.BICUBIC),
        transforms.ToTensor(),
        transforms.Normalize(mean=image_mean, std=image_std)
    ])
    prompts = []
    for i in range(len(examples['instructions'])):
        img = examples['image_name'][i]
        text = alpaca_prompt.format(examples["instructions"], f"""{examples["inputs"]}\nhttps://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/{img}?raw=true""", examples["outputs"]) + EOS_TOKEN
        prompts.append(text)
    inputs = processor(prompts, transform=image_transform, return_tensors="pt").to(device)
    inputs["labels"] = inputs["input_ids"]
    return inputs

# %%
tmp = dataset.train_test_split(test_size=0.3)
train_dataset = tmp["train"]
test_dataset = tmp["test"]
train_dataset.set_transform(tmp_transforms)
test_dataset.set_transform(tmp_transforms)

# %%
def evaluate_model(model, processor, test_dataset):
    predictions = []
    references = []
    for example in test_dataset:
        prompt = tokenizer.decode(example['input_ids'], skip_special_tokens=True)
        generated_text = do_inference(model, processor, prompt)
        predictions.append(generated_text)
        references.append(tokenizer.decode(example['labels'], skip_special_tokens=True))

    scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
    rouge_scores = {'rouge1': 0, 'rouge2': 0, 'rougeL': 0}
    bleu_scores = []

    for ref, pred in zip(references, predictions):
        rouge = scorer.score(ref, pred)
        for key in rouge_scores:
            rouge_scores[key] += rouge[key].fmeasure

        bleu_scores.append(sentence_bleu([ref.split()], pred.split()))

    rouge_scores = {key: value / len(references) for key, value in rouge_scores.items()}
    avg_bleu_score = sum(bleu_scores) / len(bleu_scores)

    return rouge_scores, avg_bleu_score

# Evaluate before training
pre_train_rouge, pre_train_bleu = evaluate_model(model, processor, test_dataset)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:649: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`.
#   warnings.warn(
# Streaming output truncated to the last 5000 lines.
#
# I'
#
#
# I'
#
# I
#
# I
#
#
# I
#
# I
#
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['soatissue','bofttissue','fracti','le','text','r']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/5484_0976904113_01_WRI-R2_M012.png?raw=true
#
# ###Response:
# ['Thereisevidenceoftorusfractureidentifiedintherightdistalradius.Normaljointspaces.\nSofttissueswellingnoted.\n.WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
#
# The
#
# The 20
#
#
# The 2
#
# The 2
# The
#
#
# The 1
# The
# The
#
# The
#
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['pronatoraign','text','r']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/3331_0913624270_01_WRI-R2_M011.png?raw=true
#
# ###Response:
# ['Thereisnoevidenceoffractureorbonyabnormalities..Thereisnoevidenceoffractureorbonyabnormalties.Normaljointspaces.Nomralsofttissuedensities..WristXrayisNormal']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The
#
#
# The 10
#
#
# The 1
#
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['pronotoraign','fracturt','text','r']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/0424_1002614279_01_WRI-R2_M011.png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
#
# I
#
# I
#
# I
#
# I
#
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['ton','r','softtissus','foue']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/1280_0847425934_01_WRI-R2_F016.png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['fracture','notorsign','text']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/0397_0512488068_01_WRI-L2_F008.png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
#
# I
#
# I
#
# I
#
# I
#
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','softtissue','softtissue','racture']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/4215_0462526361_01_WRI-L2_M010.png?raw=true
#
# ###Response:
# ['Thereisevidenceofdisplacedfractureidentifiedintheleftdistalradius.Normaljointspaces.\nSofttissueswellingnoted.\n.WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
# I'm a 1
#
#
# I
#
# I
#
#
# I
#
# I
#
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
#
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['ext','l','perosteolreaction','fracture']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/5494_0892305626_03_WRI-L1_F008.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffracturesidentifiedintheleftdistalradius.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The
#
# The 10
#
#
# The 1
#
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','r','fracture','fracture']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/0094_1111180118_02_WRI-R1_M011.png?raw=true
#
# ###Response:
# ['Thereisevidenceoftorusfractureidentifiedintherightradiusdistal\n.Normaljointspaces.\nSofttissueswellingnoted.\n.WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The
#
# The 10
#
#
# The 1
#
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','pronatorsign','fracturet']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/3610_0727924145_01_WRI-L2_F009.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintherightdistalradius.Normaljointspaces..Softtissueswellingnoted.dorsalddisplacementofdistalfragmentnoted.silverforkdeformitynoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The
#
# The 10
#
#
# The 1
#
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['recistorectiosteraction','ext']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/0367_1063849992_01_WRI-L1_M006.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffracturewithcallusformationidentifiedintheleftdistalradius..Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
#
# I'
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
#
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['cofttissus','fracturet','tracturnt','text']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/5497_0477862789_01_WRI-L1_F008.png?raw=true
#
# ###Response:
# ['Thereisevidenceoftorusfracturesidentifiedintheleftdistalradius&ulna..Normaljointspaces.\nSofttissueswellingnoted.\n.WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
# The 10
#
#
# The 1
#
#
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['fracture','fractune','periosteolreaction','text']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/0429_0211110427_03_WRI-L1_M014.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffracturewithcalusformationidentifiedinleftdistalradius.normaljointspaces.Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
# I'm a 1
#
#
# I
#
# I
#
#
# I
#
# I
#
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
#
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['periostealreaction','fracture','text','r']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/1306_0371775123_02_WRI-R2_M013.png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
#
# I
#
# I
#
# I
#
# I
#
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['pronatorsign','fracture','cst']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/3256_0593082423_01_WRI-L2_M014.png?raw=true
#
# ###Response:
# ['Thereisevidenceoftorusfractureidentifiedintheleftdistalradius.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The 10
#
#
#
# The
#
# The 1
#
# The
#
# The
#
# The
#
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','r','fracture']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/0057_0927207258_01_WRI-R2_M010.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffracturewithbowingidentifiedintherightlower3rdofradius..Normaljointspaces.\nSofttssueswellingnoted\n.WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The
#
# The 10
#
#
# The 1
#
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','r','ofttissue','softtissue','pronotersign','frac']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/5599_1221649360_01_WRI-R2_M007.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintherightdistalradius..Normaljointspaces.\nSofttissueswellingnoted.\n.WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
#
# The
#
# The 20
#
#
# The 2
#
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['softtissue','text','l']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/0198_0798640498_01_WRI-L2_M011.png?raw=true
#
# ###Response:
# ['Thereisnoevidenceoffractureorbonyabnormalities..Normalsofttissuedensities..WristXrayisNormal']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The 10
#
#
# The 1
#
#
# The 1
#
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['pronotoraion','fractur']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/0144_0934034785_01_WRI-R2_M008.png?raw=true
#
# ###Response:
# ['Thereisevidenceoftorusfractureidentifiedinthedistalrightradius.Normaljointspaces.\nSofttissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
#
# I'
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
#
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','r','softtioue','fracture','fractun']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/4726_0966094796_01_WRI-R1_F009.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffracturesidentifiedintherightdistalradius&ulna..Normaljointspaces.\nSofttissueswellingnoted.\n.WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The
#
# The 10
#
#
# The 1
#
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','r','pronatorsign']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/3493_0204488051_01_WRI-R2_M015.png?raw=true
#
# ###Response:
# ['Thereisnoevidenceoffractureorbonyabnormalities..Thereisnoevidenceoffractureorbonyabnormalties.Normaljointspaces.Nomralsofttissuedensities..WristXrayisNormal']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The
#
#
# The 10
#
#
# The 1
#
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['fracturt','periostealreaction','text']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/0313_0947475204_06_WRI-R1_F015.png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
#
# I
#
# I
#
# I
#
# I
#
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','l','softtissus','ssa']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/4963_0372871151_01_WRI-L2_F006.png?raw=true
#
# ###Response:
# ['Thereisevidenceoftorusfracturesidentifiedintheleftdistalradius&ulna..Normaljointspaces.\nSofttissueswellingnoted.\n.WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
#
# I'
#
#
# I
#
# I
#
# I
#
# I
#
#
# I
#
# I
#
# I
# I
#
# I
#
# I
#
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','periosteolreaction','fracture','pertonstealreaction','periostealreaction']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/0038_0775938700_03_WRI-L1_M014.png?raw=true
#
# ###Response:
# ['Thereisevidenceoftorusfracturesidentifiedintheleftdistalradius&ulna..Normaljointspaces.\nSofttissueswellingnoted.\n.WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The
#
#
# The
#
# The 20
#
#
# The 2
# The
#
# The
#
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','r','ofttissue','softtissue','pronotersign','frac']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/5599_1221649360_01_WRI-R2_M007.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintherightdistalradius..Normaljointspaces.\nSofttissueswellingnoted.\n.WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
#
# The
#
# The 20
#
#
# The 2
#
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The 2
# The
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['prongrsign','tent','r','fractun']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/1283_0493243006_03_WRI-R2_M012.png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
#
# I
#
# I
#
# I
#
# I
#
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','fracture','tracture']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/0480_1160356207_03_WRI-L1_M007.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintheleftdistalradius.Surgicalmetallicnailingintact..Normaljointspaces.\nSofttissueswellingnoted\n.WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The
#
# The 10
#
#
# The 1
#
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['r']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/0021_1009239861_01_WRI-R1_M015.png?raw=true
#
# ###Response:
# ['Thereisnoevidenceoffractureorbonyabnormalities.\nNormaljointspaces.\n.Normalsofttissuedensities..WristXrayisNormal']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The 10
#
#
#
# The 1
#
#
# The 1
#
# The 1
#
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
#
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','f','prongorsign','frc','cturnt','racus']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/5444_0685400914_01_WRI-R2_M010.png?raw=true
#
# ###Response:
# ['Thereisevidenceoftorusfractureidentifiedintherightdistalradius.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The
#
# The 10
#
#
# The 1
#
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['tekt','pronoigh','frac','une']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/0863_1107746940_01_WRI-L2_F007.png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
#
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['oxt','r','fractunt','fracture']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/5546_0604528200_01_WRI-R1_F010.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintherightdistalradius.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The
#
# The 10
#
#
# The 1
#
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','r','softtissue','fractune']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/5893_0708964653_01_WRI-R2_M016.png?raw=true
#
# ###Response:
# ['Thereisevidenceoftorusfracturesidentifiedintherightdistalradius..Normaljointspaces.\nSofttissueswellingnoted.\n.WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
#
# I'
#
# I
#
# I
#
#
# I
#
# I
#
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
#
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','fracture','xelorsign']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/3934_0579510072_01_WRI-L2_M010.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintheleftdistalradiusmetaphysis.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The 10
#
#
#
# The
#
# The 1
#
# The
#
# The
#
# The
#
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['cx','l','tractuns','periosteoiraction','fra','stune','peniostealreaction']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/0751_0352223092_01_WRI-L1_M015.png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
# I'm not sure, I'm not, I'm not, I'm not, I'm not, I'm not, I'm not, I'm not, I'm not, I'm not, I'm not, I'm not, I'm not, I'm not, I'm not, I'm not, I'm not, I'm not, I'm not, I'm not, I'm not, I'm not, I'm not, I'm not, I'm not,
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['oxt','r','fractunt','fracture']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/5546_0604528200_01_WRI-R1_F010.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintherightdistalradius.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The
#
# The 10
#
#
# The 1
#
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','fracture','fracture','peniostealreaction']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/0170_0537505603_04_WRI-L1_F009.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintheleftdistal3"ofradius..Normaljointspaces.\nSofttissueswellingnoted\n.WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The
#
# The 10
#
#
# The 1
#
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['txt','prongorsign','fract']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/4264_1148089961_01_WRI-L2_F007.png?raw=true
#
# ###Response:
# ['Thereisevidenceoftorusfracturesidentifiedintherightdistalradiusandulna.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
# I'm a 1
#
# I
#
#
# I
#
# I
#
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
#
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['bofttissue','fracture','fracturs']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/4737_0091826996_01_WRI-L1_M012.png?raw=true
#
# ###Response:
# ['Thereisevidenceoftorusfractureidentifiedintheleftdistalradius.Normaljointspaces.\nSofttissueswellingnoted.\n.WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
# I'm a 1
#
# I
#
#
# I
#
# I
#
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
#
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['fractunt','fracture','texs','s']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/0446_0428578304_01_WRI-R1_M013.png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
#
# I
#
# I
#
# I
#
# I
#
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','fracture','folure']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/6041_0378425522_05_WRI-L2_M012.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffracturesidentifiedinthelefttdistalradius&ulna.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The 10
#
#
#
# The
#
# The 1
#
# The
#
# The
#
# The
#
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# The
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['tracture','penostealreaction','tect']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/0422_1294991018_03_WRI-L1_M010.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureswithintemalfixationidentifiedintherightdistalradius&ulna..Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
# I'm a 1
#
# I
#
#
# I
#
# I
#
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
#
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['perniosteolraction','fracture','fracture','text']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/0065_1047068896_02_WRI-L1_F011.png?raw=true
#
# ###Response:
# ['POPnoted.\nThereisevidenceoffracturesidentifiedintheleftdistal3ofradius&ulna\n.Normaljointspaces.\nSofttissueswellingnoted.\n.WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The
#
# The 10
#
#
# The 1
#
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['softtissue','text','fractunt','factur']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/0954_0960183747_01_WRI-L2_F011.png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The 10
#
#
# The 1
#
#
# The 1
#
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','fracture','pronoloraign','lroou']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/4181_1049609915_01_WRI-L2_M009.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintheleftdistalulna.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
#
# I'
#
#
# I
#
# I
#
# I
#
# I
#
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['fracture','fracturt','text']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/1175_0324575336_01_WRI-L1_M010.png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
#
# I
#
# I
#
# I
#
# I
#
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['ext','softtisue','bon','anomoy','l']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/0363_0770982289_01_WRI-L2_M014.png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The 10
#
#
# The 1
#
#
# The 1
#
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','r','pronatorsign','fractune']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/4165_0433985928_01_WRI-R2_M011.png?raw=true
#
# ###Response:
# ['Thereisevidenceoftorusfractureidentifiedintherightdistalradius.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
#
# I'
#
# I
#
# I
#
#
# I
#
# I
#
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
#
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['ext','softtissue','cofttissue','fract','ure']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/5920_1309192150_02_WRI-L2_M017.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintheleftdistalradius..Normaljointspaces.\nSofttissueswellingnoted.\n.WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
#
# I'
#
#
# I
#
# I
#
# I
#
# I
#
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','text','rnotorsign','fracture']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/0437_1252397871_01_WRI-L2_M014.png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
#
# I
#
# I
#
# I
#
# I
#
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','pronctorsign','fractune','racture']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/3657_0627224424_01_WRI-L2_F011.png?raw=true
#
# ###Response:
# ['Thereisevidenceoftorusfracturesidentifiedintherightdistalradiusandulna.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The
#
# The 10
#
#
# The 1
#
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['fractures','softtissue','fracture','fracture','ext']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/1099_0274418034_01_WRI-L2_M013.png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
# I'm a 1
#
# I
#
#
# I
#
# I
#
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
#
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['tent','l','fracture']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/5865_0977645826_01_WRI-L1_F005.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintheleftdistalradius..Normaljointspaces.\nSofttissueswellingnoted.\n.WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
#
# I'
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
#
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','fracture','fracture']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/0839_0514599589_01_WRI-L1_F006.png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
#
# I
#
# I
#
# I
#
# I
#
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','metal','stol','si','froctuc']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/0427_0208622585_01_WRI-L2_M012.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffracturesidentifiedintheleftdistalradius&ulna.\nIntactintemalfixationwithnailingnotedintheleftdistalradius.\n.Normaljointspaces.\nSofttissueswellingnoted.\n.WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The
#
# The 10
#
#
# The 1
#
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
#
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['fracture','text']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/0035_0797029228_01_WRI-L1_F012.png?raw=true
#
# ###Response:
# ['Thereisevidenceoftorusfractureidentifiedintherightdistalradius..Normaljointspaces.\nSofttissueswellingnoted.\n.WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The
#
# The 10
#
#
# The 1
#
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['tot','r','fracturt','xt','periostealreaction','periostealreaction','frac','ture']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/1298_1098297136_03_WRI-R1_M014.png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
#
# The 1
#
#
# The 1
#
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['tert','dronatorsign','fractun','softtiss']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/5818_0746505536_01_WRI-L2_M014.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintheleftdistalradius..Normaljointspaces.\nSofttissueswellingnoted.\n.WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
#
# The 1
#
#
# The 1
#
#
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','s','fracture']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/0798_1176971459_02_WRI-R2_M010.png?raw=true
#
# ###Response:
# ['Thereisevidenceoffractureidentifiedintheleftdistalradius.\nIntactintemalfixationwithnailingnotedintheleftdistalradius.\n.Normaljointspaces,\nSofttissucswellingnoted,\n.WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The
#
# The 10
#
#
# The 1
#
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['tens','softtisone','frasture']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/4598_1146028303_01_WRI-L2_M005.png?raw=true
#
# ###Response:
# ['Thereisevidenceoftorusfractureidentifiedintheleftdistalradius.Normaljointspaces.\nSofttissueswellingnoted.\n.WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The
#
#
# The 10
#
#
# The 1
#
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['text','r','pronotorsign','acurt','frab','unc']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/3611_1153281258_01_WRI-R2_F009.png?raw=true
#
# ###Response:
# ['Thereisevidenceoftorusfracturesidentifiedintherightdistalradiusandulna.Normaljointspaces..Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The
#
# The 10
#
#
# The 1
#
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The 1
# The
# Belowisaninstructionthatdescribesatask,pairedwithaninputthatprovidesfurthercontext.Writearesponsethatappropriatelycompletestherequest.
#
# ###Instruction:
# ['BasedontheanalysisofWristXray,thefollowingissueshavebeenidentified:']
#
# ###Input:
# ["['fracturt','periosteolreaction','jcturt','text']"]
# https://github.com/aqsaHafeez/Pediatric-wrist-Radio-Reports/tree/main/Images/1007_0987815941_02_WRI-L1_M008.png?raw=true
#
# ###Response:
# ['.Softtissueswellingnoted..WristXrayisFracture']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# I'
#
#
# I
#
# I
#
# I
#
# I
#
# I
#
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# I
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)

# %%
print(f"ROUGE scores before training: {pre_train_rouge}")
print(f"BLEU score before training: {pre_train_bleu}")
# Out:
# ROUGE scores before training: {'rouge1': 0.329578092776376, 'rouge2': 0.28227899958232844, 'rougeL': 0.3084694376105493}
# BLEU score before training: 4.593152660508042e-157
